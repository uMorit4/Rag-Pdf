# %%
import pandas as pd

# %%
data = pd.read_csv("outputs/dados_consolidados_Regulamentos.csv")

# %%
data
# Out:
#            Arquivo_Origem         tipo                    fundo administrador  \
# 0  FIA - Alphakey FIA.pdf          FIA           Alphakey Ações           BTG
# 1     FIA - Atmos JCW.pdf          FIA                Atmos JCW           BTG
# 2        FIA - Encore.pdf          FIA      ENCORE LONG BIAS FC           BTG
# 3   FIA - Tarpon GT90.pdf          FIA             Tarpon GT 90           BTG
# 4           FIA - WHG.pdf          FIA     WHG LONG BIASED VIII        Intrag
# 5           FII - CF2.pdf  Imobiliário                      CF2         Vórtx
# 6           FII - CF3.pdf  Imobiliário                      CF3     Singulare
# 7          FII - RBR3.pdf  Imobiliário  RBR DESENVOLVIMENTO III           BTG
#
#                  cnpj                                        taxa_global  \
# 0  34.839.385/0001-05  1,87% (mínimo de R$ 2.500,00/mês) (máximo de 2...
# 1  22.106.186/0001-09                             máximo de 1,50% ao ano
# ...
